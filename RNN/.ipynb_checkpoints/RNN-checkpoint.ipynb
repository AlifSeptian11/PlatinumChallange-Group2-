# %%
import pandas as pd
import numpy as np
import pickle
import re
import matplotlib.pyplot as plt
import sqlite3 as sq
from collections import defaultdict
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Embedding, LSTM, SpatialDropout1D, SimpleRNN, Activation, Flatten
from tensorflow.keras import optimizers, callbacks
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# WARNING:tensorflow:From C:\Users\Reza Fakhrurrozi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Prepare Dataset

# %%
db = sq.connect('C:/Users/Reza Fakhrurrozi/Documents/GitHub/PlatinumChallange-Group2-/database_pl.db', check_same_thread = False)
q_data = 'SELECT * FROM data'
df = pd.read_sql_query(q_data, db)
df.head(10)
# Out:
#                                                Tweet     Label
# 0  warung ini dimiliki oleh pengusaha pabrik tahu...  positive
# 1  mohon ulama lurus dan k212 mmbri hujjah partai...   neutral
# 2  lokasi strategis di jalan sumatra bandung temp...  positive
# 3  betapa bahagia nya diri ini saat unboxing pake...  positive
# 4  aduh jadi mahasiswa jangan sombong dong kasih ...  negative
# 5  makanan beragam harga makanan di food stall ak...  positive
# 6  pakai kartu kredit baca tidak untung malah rug...  negative
# 7  tempat unik bagus buat foto makanan enak pegaw...  positive
# 8  saya bersama keluarga baru saja menikmati peng...  positive
# 9                                          bersyukur  positive

# %%
df.Label.value_counts()
# Out:
# Label
# positive    6383
# negative    3412
# neutral     1138
# Name: count, dtype: int64

# %% [markdown]
# # Text Normalization

# %%
def cleansing(sent):
    string = sent.lower()
    string = re.sub(r'[^a-zA-Z0-9]', ' ', string)
    return string

# %%
df['Tweet_Clean'] = df.Tweet.apply(cleansing)
df.head()

# %% [markdown]
# # Feature Label Classification

# %%
# memfilter data berdasarkan label
df_positive = df[df['Label'] == 'positive']
df_negative = df[df['Label'] == 'negative']
df_neutral = df[df['Label'] == 'neutral']

# menyeimbangkan label netral dengan label negatif
df_neutral_over = df_neutral.sample(df_negative.shape[0], replace=True)

#menggabungan semua data
df = pd.concat([df_positive, df_negative, df_neutral_over])

# mengecek kembali
label_counts = df['Label'].value_counts()
print(label_counts)
# Out:
# Label
# positive    6383
# negative    3412
# neutral     3412
# Name: count, dtype: int64

# %%
# Group data tweet
positive_tweet = df.loc[df['Label']=='positive'].Tweet.tolist()
negative_tweet = df.loc[df['Label']=='negative'].Tweet.tolist()
neutral_tweet = df.loc[df['Label']=='neutral'].Tweet.tolist()

# Group data label
positive_label = df.loc[df['Label']=='positive'].Label.tolist()
negative_label = df.loc[df['Label']=='negative'].Label.tolist()
neutral_label = df.loc[df['Label']=='neutral'].Label.tolist()

total_data = positive_tweet + negative_tweet + neutral_tweet
labels = positive_label + neutral_label + negative_label

print("Positive: %s, Negative: %s, Neutral: %s" % (len(positive_tweet), len(negative_tweet), len(neutral_tweet)))
print("Total data: %s" % len(total_data))
print("Total labels: %s" % len(labels))
# Out:
# Positive: 6383, Negative: 3412, Neutral: 3412
# Total data: 13207
# Total labels: 13207

# %% [markdown]
# # Feature Extraction

# %%
max_features = 5000
tokenizer = Tokenizer(num_words=max_features, split=' ', lower=True)
tokenizer.fit_on_texts(total_data)
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print("tokenizer.pickle has been created!")

X = tokenizer.texts_to_sequences(total_data)

vocab_size = len(tokenizer.word_index)
maxlen = max(len(x) for x in X)

X = pad_sequences(X)
with open('x_pad_sequences.pickle', 'wb') as handle:
    pickle.dump(X, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print("x_pad_sequences.pickle has been created!")
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print("tokenizer.pickle has been created!")
# Out:
# tokenizer.pickle has been created!
# x_pad_sequences.pickle has been created!
# tokenizer.pickle has been created!

# %% [markdown]
# # Train-Test Data Split

# %%
Y = pd.get_dummies(labels)
Y = Y.values

with open('y_labels.pickle', 'wb') as handle:
    pickle.dump(Y, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print("y_labels.pickle has created!")
# Out:
# y_labels.pickle has created!

# %%
file = open("x_pad_sequences.pickle", 'rb')
X = pickle.load(file)
file.close()

file = open("y_labels.pickle", 'rb')
Y = pickle.load(file)
file.close()

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# # Model Training

# %%
kf = KFold(n_splits=5,random_state=42,shuffle=True)

accuracies = []

y = Y

embed_dim = 200
units = 64

for iteration, data in enumerate(kf.split(X), start=1):
    data_train   = X[data[0]]
    target_train = y[data[0]]

    data_test    = X[data[1]]
    target_test  = y[data[1]]

    model = Sequential()
    model.add(Embedding(max_features, embed_dim, input_length=X.shape[1]))
    model.add(SimpleRNN(units, dropout=0.8))
    model.add(Dense(3, activation='softmax'))
    #model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

    adam = optimizers.Adam(learning_rate=0.00005)
    model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)
    history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=1, callbacks=[es])

    predictions = model.predict(X_test)
    y_pred = predictions

    accuracy = accuracy_score(y_test.argmax(axis=1), y_pred.argmax(axis=1))

    print("Training -", iteration)
    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1)))
    print("======================================================")

    accuracies.append(accuracy)

average_accuracy = np.mean(accuracies)

print()
print()
print()
print("Rata-rata Accuracy: ", round(average_accuracy,4))
# Out:
# WARNING:tensorflow:From C:\Users\Reza Fakhrurrozi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Reza Fakhrurrozi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Reza Fakhrurrozi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 331/331 [==============================] - 16s 39ms/step - loss: 0.9833 - accuracy: 0.5141 - val_loss: 0.8232 - val_accuracy: 0.6264
# Epoch 2/50
# 331/331 [==============================] - 14s 42ms/step - loss: 0.7779 - accuracy: 0.6600 - val_loss: 0.7241 - val_accuracy: 0.6681
# Epoch 3/50
# 331/331 [==============================] - 13s 41ms/step - loss: 0.7040 - accuracy: 0.6937 - val_loss: 0.6616 - val_accuracy: 0.6930
# Epoch 4/50
# 331/331 [==============================] - 13s 39ms/step - loss: 0.6471 - accuracy: 0.7196 - val_loss: 0.6075 - val_accuracy: 0.7737
# Epoch 5/50
# 331/331 [==============================] - 14s 43ms/step - loss: 0.6014 - accuracy: 0.7488 - val_loss: 0.5574 - val_accuracy: 0.8062
# Epoch 6/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.5711 - accuracy: 0.7656 - val_loss: 0.5168 - val_accuracy: 0.8270
# Epoch 7/50
# 331/331 [==============================] - 13s 40ms/step - loss: 0.5265 - accuracy: 0.7944 - val_loss: 0.4774 - val_accuracy: 0.8448
# Epoch 8/50
# 331/331 [==============================] - 13s 39ms/step - loss: 0.4866 - accuracy: 0.8108 - val_loss: 0.4665 - val_accuracy: 0.8433
# Epoch 9/50
# 331/331 [==============================] - 13s 39ms/step - loss: 0.4562 - accuracy: 0.8333 - val_loss: 0.4183 - val_accuracy: 0.8611
# Epoch 10/50
# 331/331 [==============================] - 12s 36ms/step - loss: 0.4265 - accuracy: 0.8410 - val_loss: 0.4006 - val_accuracy: 0.8671
# Epoch 11/50
# 331/331 [==============================] - 13s 39ms/step - loss: 0.4053 - accuracy: 0.8509 - val_loss: 0.3857 - val_accuracy: 0.8690
# Epoch 12/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.3880 - accuracy: 0.8539 - val_loss: 0.3632 - val_accuracy: 0.8766
# Epoch 13/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.3648 - accuracy: 0.8691 - val_loss: 0.3534 - val_accuracy: 0.8789
# Epoch 14/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.3432 - accuracy: 0.8728 - val_loss: 0.3459 - val_accuracy: 0.8812
# Epoch 15/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.3283 - accuracy: 0.8805 - val_loss: 0.3272 - val_accuracy: 0.8857
# Epoch 16/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.3112 - accuracy: 0.8868 - val_loss: 0.3306 - val_accuracy: 0.8834
# Epoch 17/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2968 - accuracy: 0.8930 - val_loss: 0.3112 - val_accuracy: 0.8883
# Epoch 18/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2858 - accuracy: 0.8958 - val_loss: 0.3014 - val_accuracy: 0.8948
# Epoch 19/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2766 - accuracy: 0.9020 - val_loss: 0.3089 - val_accuracy: 0.8929
# Epoch 20/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2622 - accuracy: 0.9065 - val_loss: 0.2980 - val_accuracy: 0.8944
# Epoch 21/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2534 - accuracy: 0.9086 - val_loss: 0.2825 - val_accuracy: 0.9031
# Epoch 22/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2411 - accuracy: 0.9112 - val_loss: 0.2837 - val_accuracy: 0.9005
# Epoch 23/50
# 331/331 [==============================] - 12s 38ms/step - loss: 0.2341 - accuracy: 0.9198 - val_loss: 0.2740 - val_accuracy: 0.9020
# Epoch 24/50
# 331/331 [==============================] - 13s 39ms/step - loss: 0.2225 - accuracy: 0.9191 - val_loss: 0.2850 - val_accuracy: 0.8989
# Epoch 25/50
# 331/331 [==============================] - 13s 40ms/step - loss: 0.2179 - accuracy: 0.9240 - val_loss: 0.2668 - val_accuracy: 0.9058
# Epoch 26/50
# 331/331 [==============================] - 13s 40ms/step - loss: 0.2094 - accuracy: 0.9229 - val_loss: 0.2631 - val_accuracy: 0.9050
# Epoch 27/50
# 331/331 [==============================] - 14s 42ms/step - loss: 0.1997 - accuracy: 0.9273 - val_loss: 0.2705 - val_accuracy: 0.9042
# Epoch 28/50
# 331/331 [==============================] - 13s 39ms/step - loss: 0.1956 - accuracy: 0.9283 - val_loss: 0.2649 - val_accuracy: 0.9065
# Epoch 28: early stopping
# 83/83 [==============================] - 2s 9ms/step
# Training - 1
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94       662
#            1       0.82      0.88      0.85       709
#            2       0.95      0.89      0.92      1271
#
#     accuracy                           0.91      2642
#    macro avg       0.90      0.91      0.90      2642
# weighted avg       0.91      0.91      0.91      2642
#
# ======================================================
# Epoch 1/50
# 331/331 [==============================] - 16s 42ms/step - loss: 0.9999 - accuracy: 0.4827 - val_loss: 0.8192 - val_accuracy: 0.6344
# Epoch 2/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.7901 - accuracy: 0.6491 - val_loss: 0.7549 - val_accuracy: 0.6488
# Epoch 3/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.7175 - accuracy: 0.6842 - val_loss: 0.6720 - val_accuracy: 0.6938
# Epoch 4/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.6592 - accuracy: 0.7175 - val_loss: 0.6172 - val_accuracy: 0.7392
# Epoch 5/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.6227 - accuracy: 0.7424 - val_loss: 0.5820 - val_accuracy: 0.7960
# Epoch 6/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.5744 - accuracy: 0.7672 - val_loss: 0.5284 - val_accuracy: 0.8217
# Epoch 7/50
# 331/331 [==============================] - 13s 39ms/step - loss: 0.5317 - accuracy: 0.7928 - val_loss: 0.4964 - val_accuracy: 0.8293
# Epoch 8/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.4926 - accuracy: 0.8128 - val_loss: 0.4491 - val_accuracy: 0.8478
# Epoch 9/50
# 331/331 [==============================] - 13s 41ms/step - loss: 0.4546 - accuracy: 0.8293 - val_loss: 0.4311 - val_accuracy: 0.8467
# Epoch 10/50
# 331/331 [==============================] - 12s 36ms/step - loss: 0.4250 - accuracy: 0.8424 - val_loss: 0.4049 - val_accuracy: 0.8497
# Epoch 11/50
# 331/331 [==============================] - 12s 36ms/step - loss: 0.3946 - accuracy: 0.8509 - val_loss: 0.3794 - val_accuracy: 0.8683
# Epoch 12/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.3730 - accuracy: 0.8570 - val_loss: 0.3509 - val_accuracy: 0.8751
# Epoch 13/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.3477 - accuracy: 0.8689 - val_loss: 0.3370 - val_accuracy: 0.8789
# Epoch 14/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.3331 - accuracy: 0.8763 - val_loss: 0.3337 - val_accuracy: 0.8864
# Epoch 15/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.3064 - accuracy: 0.8858 - val_loss: 0.3184 - val_accuracy: 0.8895
# Epoch 16/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.3027 - accuracy: 0.8874 - val_loss: 0.3140 - val_accuracy: 0.8944
# Epoch 17/50
# 331/331 [==============================] - 12s 36ms/step - loss: 0.2837 - accuracy: 0.8952 - val_loss: 0.3195 - val_accuracy: 0.8883
# Epoch 18/50
# 331/331 [==============================] - 12s 36ms/step - loss: 0.2712 - accuracy: 0.9011 - val_loss: 0.2943 - val_accuracy: 0.8895
# Epoch 19/50
# 331/331 [==============================] - 12s 36ms/step - loss: 0.2656 - accuracy: 0.9018 - val_loss: 0.2905 - val_accuracy: 0.8974
# Epoch 20/50
# 331/331 [==============================] - 12s 36ms/step - loss: 0.2492 - accuracy: 0.9094 - val_loss: 0.2770 - val_accuracy: 0.8989
# Epoch 21/50
# 331/331 [==============================] - 12s 36ms/step - loss: 0.2408 - accuracy: 0.9125 - val_loss: 0.2806 - val_accuracy: 0.9031
# Epoch 22/50
# 331/331 [==============================] - 13s 39ms/step - loss: 0.2337 - accuracy: 0.9141 - val_loss: 0.2804 - val_accuracy: 0.9039
# Epoch 22: early stopping
# 83/83 [==============================] - 1s 9ms/step
# Training - 2
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.93       662
#            1       0.87      0.81      0.84       709
#            2       0.92      0.92      0.92      1271
#
#     accuracy                           0.90      2642
#    macro avg       0.90      0.90      0.90      2642
# weighted avg       0.90      0.90      0.90      2642
#
# ======================================================
# Epoch 1/50
# 331/331 [==============================] - 16s 38ms/step - loss: 0.9768 - accuracy: 0.5129 - val_loss: 0.8417 - val_accuracy: 0.6223
# Epoch 2/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.7987 - accuracy: 0.6479 - val_loss: 0.7520 - val_accuracy: 0.6718
# Epoch 3/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.7427 - accuracy: 0.6804 - val_loss: 0.7002 - val_accuracy: 0.6889
# Epoch 4/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.6948 - accuracy: 0.7069 - val_loss: 0.6498 - val_accuracy: 0.7089
# Epoch 5/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.6555 - accuracy: 0.7270 - val_loss: 0.6155 - val_accuracy: 0.7475
# Epoch 6/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.6094 - accuracy: 0.7559 - val_loss: 0.5786 - val_accuracy: 0.7604
# Epoch 7/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.5804 - accuracy: 0.7673 - val_loss: 0.5651 - val_accuracy: 0.7627
# Epoch 8/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.5415 - accuracy: 0.7943 - val_loss: 0.5189 - val_accuracy: 0.7983
# Epoch 9/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.5008 - accuracy: 0.8097 - val_loss: 0.4760 - val_accuracy: 0.8168
# Epoch 10/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.4636 - accuracy: 0.8282 - val_loss: 0.4347 - val_accuracy: 0.8425
# Epoch 11/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.4219 - accuracy: 0.8458 - val_loss: 0.4065 - val_accuracy: 0.8524
# Epoch 12/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.3920 - accuracy: 0.8590 - val_loss: 0.3660 - val_accuracy: 0.8808
# Epoch 13/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.3634 - accuracy: 0.8676 - val_loss: 0.3479 - val_accuracy: 0.8849
# Epoch 14/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.3379 - accuracy: 0.8743 - val_loss: 0.3383 - val_accuracy: 0.8781
# Epoch 15/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.3230 - accuracy: 0.8817 - val_loss: 0.3376 - val_accuracy: 0.8804
# Epoch 16/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2999 - accuracy: 0.8918 - val_loss: 0.3144 - val_accuracy: 0.8952
# Epoch 17/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2919 - accuracy: 0.8909 - val_loss: 0.3089 - val_accuracy: 0.8910
# Epoch 18/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2719 - accuracy: 0.9003 - val_loss: 0.2945 - val_accuracy: 0.8982
# Epoch 19/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2645 - accuracy: 0.9067 - val_loss: 0.2904 - val_accuracy: 0.9012
# Epoch 20/50
# 331/331 [==============================] - 12s 36ms/step - loss: 0.2520 - accuracy: 0.9079 - val_loss: 0.2985 - val_accuracy: 0.8970
# Epoch 21/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2416 - accuracy: 0.9139 - val_loss: 0.2840 - val_accuracy: 0.9027
# Epoch 22/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2297 - accuracy: 0.9143 - val_loss: 0.2889 - val_accuracy: 0.8997
# Epoch 23/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2228 - accuracy: 0.9159 - val_loss: 0.2816 - val_accuracy: 0.9054
# Epoch 24/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2167 - accuracy: 0.9212 - val_loss: 0.2691 - val_accuracy: 0.9061
# Epoch 25/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2039 - accuracy: 0.9262 - val_loss: 0.2643 - val_accuracy: 0.9065
# Epoch 26/50
# 331/331 [==============================] - 12s 38ms/step - loss: 0.2000 - accuracy: 0.9279 - val_loss: 0.2762 - val_accuracy: 0.8989
# Epoch 27/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.1931 - accuracy: 0.9300 - val_loss: 0.2773 - val_accuracy: 0.9039
# Epoch 27: early stopping
# 83/83 [==============================] - 1s 9ms/step
# Training - 3
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93       662
#            1       0.88      0.81      0.84       709
#            2       0.92      0.92      0.92      1271
#
#     accuracy                           0.90      2642
#    macro avg       0.90      0.90      0.90      2642
# weighted avg       0.90      0.90      0.90      2642
#
# ======================================================
# Epoch 1/50
# 331/331 [==============================] - 16s 40ms/step - loss: 0.9693 - accuracy: 0.5282 - val_loss: 0.8056 - val_accuracy: 0.6374
# Epoch 2/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.7802 - accuracy: 0.6593 - val_loss: 0.7201 - val_accuracy: 0.6877
# Epoch 3/50
# 331/331 [==============================] - 13s 39ms/step - loss: 0.7128 - accuracy: 0.6896 - val_loss: 0.6569 - val_accuracy: 0.7165
# Epoch 4/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.6669 - accuracy: 0.7139 - val_loss: 0.6254 - val_accuracy: 0.7142
# Epoch 5/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.6213 - accuracy: 0.7364 - val_loss: 0.5729 - val_accuracy: 0.7718
# Epoch 6/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.5713 - accuracy: 0.7679 - val_loss: 0.5557 - val_accuracy: 0.7479
# Epoch 7/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.5177 - accuracy: 0.7997 - val_loss: 0.4779 - val_accuracy: 0.8036
# Epoch 8/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.4701 - accuracy: 0.8239 - val_loss: 0.4367 - val_accuracy: 0.8425
# Epoch 9/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.4372 - accuracy: 0.8374 - val_loss: 0.4051 - val_accuracy: 0.8497
# Epoch 10/50
# 331/331 [==============================] - 12s 38ms/step - loss: 0.4016 - accuracy: 0.8533 - val_loss: 0.3654 - val_accuracy: 0.8736
# Epoch 11/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.3781 - accuracy: 0.8607 - val_loss: 0.3475 - val_accuracy: 0.8766
# Epoch 12/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.3568 - accuracy: 0.8683 - val_loss: 0.3466 - val_accuracy: 0.8800
# Epoch 13/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.3416 - accuracy: 0.8722 - val_loss: 0.3267 - val_accuracy: 0.8846
# Epoch 14/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.3237 - accuracy: 0.8787 - val_loss: 0.3208 - val_accuracy: 0.8872
# Epoch 15/50
# 331/331 [==============================] - 13s 39ms/step - loss: 0.2998 - accuracy: 0.8904 - val_loss: 0.3129 - val_accuracy: 0.8876
# Epoch 16/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2949 - accuracy: 0.8922 - val_loss: 0.2917 - val_accuracy: 0.9023
# Epoch 17/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.2770 - accuracy: 0.8990 - val_loss: 0.3006 - val_accuracy: 0.8944
# Epoch 18/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.2701 - accuracy: 0.9026 - val_loss: 0.2922 - val_accuracy: 0.8978
# Epoch 18: early stopping
# 83/83 [==============================] - 1s 9ms/step
# Training - 4
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92       662
#            1       0.88      0.79      0.83       709
#            2       0.92      0.92      0.92      1271
#
#     accuracy                           0.90      2642
#    macro avg       0.89      0.89      0.89      2642
# weighted avg       0.90      0.90      0.90      2642
#
# ======================================================
# Epoch 1/50
# 331/331 [==============================] - 15s 39ms/step - loss: 0.9931 - accuracy: 0.4922 - val_loss: 0.8224 - val_accuracy: 0.6188
# Epoch 2/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.7990 - accuracy: 0.6444 - val_loss: 0.7594 - val_accuracy: 0.6620
# Epoch 3/50
# 331/331 [==============================] - 12s 38ms/step - loss: 0.7438 - accuracy: 0.6773 - val_loss: 0.7125 - val_accuracy: 0.6730
# Epoch 4/50
# 331/331 [==============================] - 12s 38ms/step - loss: 0.7010 - accuracy: 0.6960 - val_loss: 0.6725 - val_accuracy: 0.6995
# Epoch 5/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.6594 - accuracy: 0.7140 - val_loss: 0.6360 - val_accuracy: 0.7169
# Epoch 6/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.6294 - accuracy: 0.7315 - val_loss: 0.6175 - val_accuracy: 0.7195
# Epoch 7/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.6020 - accuracy: 0.7460 - val_loss: 0.5799 - val_accuracy: 0.7597
# Epoch 8/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.5588 - accuracy: 0.7738 - val_loss: 0.5368 - val_accuracy: 0.8134
# Epoch 9/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.5265 - accuracy: 0.7957 - val_loss: 0.5017 - val_accuracy: 0.8229
# Epoch 10/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.4864 - accuracy: 0.8132 - val_loss: 0.4667 - val_accuracy: 0.8342
# Epoch 11/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.4556 - accuracy: 0.8290 - val_loss: 0.4312 - val_accuracy: 0.8444
# Epoch 12/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.4195 - accuracy: 0.8434 - val_loss: 0.4480 - val_accuracy: 0.8255
# Epoch 13/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.3939 - accuracy: 0.8530 - val_loss: 0.4003 - val_accuracy: 0.8516
# Epoch 14/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.3669 - accuracy: 0.8625 - val_loss: 0.3652 - val_accuracy: 0.8709
# Epoch 15/50
# 331/331 [==============================] - 14s 41ms/step - loss: 0.3429 - accuracy: 0.8713 - val_loss: 0.3582 - val_accuracy: 0.8721
# Epoch 16/50
# 331/331 [==============================] - 12s 36ms/step - loss: 0.3220 - accuracy: 0.8767 - val_loss: 0.3368 - val_accuracy: 0.8861
# Epoch 17/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.3042 - accuracy: 0.8877 - val_loss: 0.3243 - val_accuracy: 0.8849
# Epoch 18/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2895 - accuracy: 0.8915 - val_loss: 0.3116 - val_accuracy: 0.8940
# Epoch 19/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.2700 - accuracy: 0.8996 - val_loss: 0.3024 - val_accuracy: 0.8963
# Epoch 20/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2618 - accuracy: 0.9043 - val_loss: 0.2950 - val_accuracy: 0.8986
# Epoch 21/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2530 - accuracy: 0.9066 - val_loss: 0.2838 - val_accuracy: 0.9005
# Epoch 22/50
# 331/331 [==============================] - 13s 38ms/step - loss: 0.2373 - accuracy: 0.9129 - val_loss: 0.2871 - val_accuracy: 0.9027
# Epoch 23/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2289 - accuracy: 0.9145 - val_loss: 0.2761 - val_accuracy: 0.9039
# Epoch 24/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2191 - accuracy: 0.9192 - val_loss: 0.2638 - val_accuracy: 0.9050
# Epoch 25/50
# 331/331 [==============================] - 12s 37ms/step - loss: 0.2103 - accuracy: 0.9228 - val_loss: 0.2700 - val_accuracy: 0.9073
# Epoch 26/50
# 331/331 [==============================] - 13s 39ms/step - loss: 0.2023 - accuracy: 0.9278 - val_loss: 0.2707 - val_accuracy: 0.9046
# Epoch 26: early stopping
# 83/83 [==============================] - 1s 9ms/step
# Training - 5
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.94       662
#            1       0.89      0.80      0.84       709
#            2       0.91      0.93      0.92      1271
#
#     accuracy                           0.90      2642
#    macro avg       0.90      0.90      0.90      2642
# weighted avg       0.90      0.90      0.90      2642
#
# ======================================================
#
#
#
# Rata-rata Accuracy:  0.9033

# %% [markdown]
# # Evalution

# %%
plt.style.use('ggplot')

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12,5))
    
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

# %matplotlib inline
plot_history(history)

# %%
# menyimpan model

model.save('model.h5')
print("Model has created!")
# Out:
# Model has created!
# C:\Users\Reza Fakhrurrozi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
input_text = """Rasa syukur, cukup"""

def cleansing(sent):
    string = sent.lower()
    string = re.sub(r'[^a-zA-Z0-9]', ' ', string)
    return string

sentiment = ['positive', 'neutral', 'negative']

text = [cleansing(input_text)]
predicted = tokenizer.texts_to_sequences(text)
guess = pad_sequences(predicted, maxlen=X.shape[1])

model = load_model('model.h5')
prediction = model.predict(guess)
polarity = np.argmax(prediction[0])
hasil = sentiment[polarity]

print("Text: ", text[0])
print("Sentiment: ", hasil)
# Out:
# 1/1 [==============================] - 0s 389ms/step
# Text:  rasa syukur  cukup
# Sentiment:  negative

# %%
input_text = """terima kasih"""

def cleansing(sent):
    string = sent.lower()
    string = re.sub(r'[^a-zA-Z0-9]', ' ', string)
    return string

sentiment = ['positive', 'neutral', 'negative']

text = [cleansing(input_text)]
predicted = tokenizer.texts_to_sequences(text)
guess = pad_sequences(predicted, maxlen=X.shape[1])

model = load_model('model.h5')
prediction = model.predict(guess)
polarity = np.argmax(prediction[0])
hasil = sentiment[polarity]

print("Text: ", text[0])
print("Sentiment: ", hasil)
