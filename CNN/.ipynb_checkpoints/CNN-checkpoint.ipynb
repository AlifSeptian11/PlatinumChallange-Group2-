# %%
import pandas as pd
import numpy as np
import pickle
import re
import matplotlib.pyplot as plt
import sqlite3 as sq
from collections import defaultdict
from sklearn import metrics
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Embedding, LSTM, SpatialDropout1D, Activation, Flatten
from tensorflow.keras import layers, optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard

# %%
db = sq.connect('C:/Users/Reza Fakhrurrozi/Documents/GitHub/PlatinumChallange-Group2-/database_pl.db', check_same_thread = False)
q_data = 'SELECT * FROM data'
df = pd.read_sql_query(q_data, db)
df.head(10)
# Out:
#                                                Tweet     Label
# 0  warung ini dimiliki oleh pengusaha pabrik tahu...  positive
# 1  mohon ulama lurus dan k212 mmbri hujjah partai...   neutral
# 2  lokasi strategis di jalan sumatra bandung temp...  positive
# 3  betapa bahagia nya diri ini saat unboxing pake...  positive
# 4  aduh jadi mahasiswa jangan sombong dong kasih ...  negative
# 5  makanan beragam harga makanan di food stall ak...  positive
# 6  pakai kartu kredit baca tidak untung malah rug...  negative
# 7  tempat unik bagus buat foto makanan enak pegaw...  positive
# 8  saya bersama keluarga baru saja menikmati peng...  positive
# 9                                          bersyukur  positive

# %%
df.Label.value_counts()
# Out:
# Label
# positive    6383
# negative    3412
# neutral     1138
# Name: count, dtype: int64

# %%
def cleansing(sent):
    string = sent.lower()
    string = re.sub(r'[^a-zA-Z0-9]', ' ', string)
    return string

# %%
df['Tweet_Clean'] = df.Tweet.apply(cleansing)
df.head()
# Out:
#                                                Tweet     Label  \
# 0  warung ini dimiliki oleh pengusaha pabrik tahu...  positive
# 1  mohon ulama lurus dan k212 mmbri hujjah partai...   neutral
# 2  lokasi strategis di jalan sumatra bandung temp...  positive
# 3  betapa bahagia nya diri ini saat unboxing pake...  positive
# 4  aduh jadi mahasiswa jangan sombong dong kasih ...  negative
#
#                                          Tweet_Clean
# 0  warung ini dimiliki oleh pengusaha pabrik tahu...
# 1  mohon ulama lurus dan k212 mmbri hujjah partai...
# 2  lokasi strategis di jalan sumatra bandung temp...
# 3  betapa bahagia nya diri ini saat unboxing pake...
# 4  aduh jadi mahasiswa jangan sombong dong kasih ...

# %%
# Group data tweet
positive_tweet = df.loc[df['Label']=='positive'].Tweet.tolist()
negative_tweet = df.loc[df['Label']=='negative'].Tweet.tolist()
neutral_tweet = df.loc[df['Label']=='neutral'].Tweet.tolist()

# Group data label
positive_label = df.loc[df['Label']=='positive'].Label.tolist()
negative_label = df.loc[df['Label']=='negative'].Label.tolist()
neutral_label = df.loc[df['Label']=='neutral'].Label.tolist()

total_data = positive_tweet + negative_tweet + neutral_tweet
labels = positive_label + neutral_label + negative_label

print("Positive: %s, Negative: %s, Neutral: %s" % (len(positive_tweet), len(negative_tweet), len(neutral_tweet)))
print("Total data: %s" % len(total_data))
print("Total labels: %s" % len(labels))
# Out:
# Positive: 6383, Negative: 3412, Neutral: 1138
# Total data: 10933
# Total labels: 10933

# %%
max_features = 5000
tokenizer = Tokenizer(num_words=max_features, split=' ', lower=True)
tokenizer.fit_on_texts(total_data)
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print("tokenizer.pickle has been created!")

X = tokenizer.texts_to_sequences(total_data)

vocab_size = len(tokenizer.word_index)
maxlen = max(len(x) for x in X)

X = pad_sequences(X)
with open('x_pad_sequences.pickle', 'wb') as handle:
    pickle.dump(X, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print("x_pad_sequences.pickle has been created!")
# Out:
# tokenizer.pickle has been created!
# x_pad_sequences.pickle has been created!

# %%
Y = pd.get_dummies(labels)
Y = Y.values

with open('y_labels.pickle', 'wb') as handle:
    pickle.dump(Y, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print("y_labels.pickle has created!")
# Out:
# y_labels.pickle has created!

# %%
file = open("x_pad_sequences.pickle", 'rb')
X = pickle.load(file)
file.close()

file = open("y_labels.pickle", 'rb')
Y = pickle.load(file)
file.close()

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
embed_dim = 200

model = Sequential()
model.add(Embedding(max_features, embed_dim, input_length=maxlen))
model.add(layers.Conv1D(128, 5, activation='relu'))
model.add(layers.GlobalMaxPooling1D())
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(3, activation='softmax'))
          
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=1, callbacks=[es])
# Out:
# WARNING:tensorflow:From C:\Users\Reza Fakhrurrozi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Reza Fakhrurrozi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 90, 200)           1000000
#
#  conv1d (Conv1D)             (None, 86, 128)           128128
#
#  global_max_pooling1d (Glob  (None, 128)               0
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 10)                1290
#
#  dense_1 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 1129451 (4.31 MB)
# Trainable params: 1129451 (4.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Reza Fakhrurrozi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Reza Fakhrurrozi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 274/274 [==============================] - 12s 34ms/step - loss: 0.3584 - accuracy: 0.7678 - val_loss: 0.3054 - val_accuracy: 0.7984
# Epoch 2/50
# 274/274 [==============================] - 9s 33ms/step - loss: 0.2406 - accuracy: 0.8419 - val_loss: 0.3020 - val_accuracy: 0.8061
# Epoch 3/50
# 274/274 [==============================] - 9s 33ms/step - loss: 0.1587 - accuracy: 0.9005 - val_loss: 0.3319 - val_accuracy: 0.7942
# Epoch 4/50
# 274/274 [==============================] - 9s 33ms/step - loss: 0.0746 - accuracy: 0.9658 - val_loss: 0.4158 - val_accuracy: 0.7897
# Epoch 4: early stopping

# %%
predictions = model.predict(X_test)
y_pred = predictions
matrix_test = metrics.classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1))
print("Testing selesai")
print(matrix_test)
# Out:
# 69/69 [==============================] - 1s 10ms/step
# Testing selesai
#               precision    recall  f1-score   support
#
#            0       0.69      0.74      0.71       681
#            1       0.35      0.20      0.25       235
#            2       0.89      0.93      0.91      1271
#
#     accuracy                           0.79      2187
#    macro avg       0.64      0.62      0.62      2187
# weighted avg       0.77      0.79      0.78      2187

# %%
kf = KFold(n_splits=5,random_state=42,shuffle=True)

accuracies = []

y = Y

embed_dim = 200

for iteration, data in enumerate(kf.split(X), start=1):
    data_train   = X[data[0]]
    target_train = y[data[0]]

    data_test    = X[data[1]]
    target_test  = y[data[1]]

    model = Sequential()
    model.add(Embedding(max_features, embed_dim, input_length=maxlen))
    model.add(layers.Conv1D(128, 5, activation='relu'))
    model.add(layers.GlobalMaxPooling1D())
    model.add(layers.Dense(10, activation='relu'))
    model.add(layers.Dense(3, activation='softmax'))
          
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())

    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)
    history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=1, callbacks=[es])

    predictions = model.predict(X_test)
    y_pred = predictions

    accuracy = accuracy_score(y_test.argmax(axis=1), y_pred.argmax(axis=1))

    print("Training -", iteration)
    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1)))
    print("======================================================")

    accuracies.append(accuracy)

average_accuracy = np.mean(accuracies)

print()
print()
print()
print("Rata-rata Accuracy: ", round(average_accuracy,4))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 90, 200)           1000000
#
#  conv1d_1 (Conv1D)           (None, 86, 128)           128128
#
#  global_max_pooling1d_1 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_2 (Dense)             (None, 10)                1290
#
#  dense_3 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 1129451 (4.31 MB)
# Trainable params: 1129451 (4.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 274/274 [==============================] - 11s 35ms/step - loss: 0.3887 - accuracy: 0.7440 - val_loss: 0.3157 - val_accuracy: 0.7970
# Epoch 2/50
# 274/274 [==============================] - 9s 32ms/step - loss: 0.2598 - accuracy: 0.8351 - val_loss: 0.3068 - val_accuracy: 0.7988
# Epoch 3/50
# 274/274 [==============================] - 9s 32ms/step - loss: 0.1868 - accuracy: 0.8761 - val_loss: 0.3369 - val_accuracy: 0.7810
# Epoch 4/50
# 274/274 [==============================] - 9s 33ms/step - loss: 0.1045 - accuracy: 0.9437 - val_loss: 0.4126 - val_accuracy: 0.7769
# Epoch 4: early stopping
# 69/69 [==============================] - 1s 8ms/step
# Training - 1
#               precision    recall  f1-score   support
#
#            0       0.67      0.70      0.68       681
#            1       0.32      0.18      0.23       235
#            2       0.87      0.93      0.90      1271
#
#     accuracy                           0.78      2187
#    macro avg       0.62      0.60      0.61      2187
# weighted avg       0.75      0.78      0.76      2187
#
# ======================================================
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 90, 200)           1000000
#
#  conv1d_2 (Conv1D)           (None, 86, 128)           128128
#
#  global_max_pooling1d_2 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_4 (Dense)             (None, 10)                1290
#
#  dense_5 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 1129451 (4.31 MB)
# Trainable params: 1129451 (4.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 274/274 [==============================] - 11s 34ms/step - loss: 0.3687 - accuracy: 0.7545 - val_loss: 0.3081 - val_accuracy: 0.8080
# Epoch 2/50
# 274/274 [==============================] - 9s 33ms/step - loss: 0.2520 - accuracy: 0.8432 - val_loss: 0.3031 - val_accuracy: 0.8029
# Epoch 3/50
# 274/274 [==============================] - 9s 33ms/step - loss: 0.1851 - accuracy: 0.8762 - val_loss: 0.3314 - val_accuracy: 0.7819
# Epoch 4/50
# 274/274 [==============================] - 9s 34ms/step - loss: 0.1160 - accuracy: 0.9354 - val_loss: 0.3854 - val_accuracy: 0.7732
# Epoch 4: early stopping
# 69/69 [==============================] - 1s 8ms/step
# Training - 2
#               precision    recall  f1-score   support
#
#            0       0.69      0.65      0.67       681
#            1       0.31      0.23      0.26       235
#            2       0.87      0.94      0.90      1271
#
#     accuracy                           0.77      2187
#    macro avg       0.62      0.60      0.61      2187
# weighted avg       0.75      0.77      0.76      2187
#
# ======================================================
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 90, 200)           1000000
#
#  conv1d_3 (Conv1D)           (None, 86, 128)           128128
#
#  global_max_pooling1d_3 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_6 (Dense)             (None, 10)                1290
#
#  dense_7 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 1129451 (4.31 MB)
# Trainable params: 1129451 (4.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 274/274 [==============================] - 11s 34ms/step - loss: 0.3629 - accuracy: 0.7653 - val_loss: 0.3041 - val_accuracy: 0.7993
# Epoch 2/50
# 274/274 [==============================] - 9s 32ms/step - loss: 0.2402 - accuracy: 0.8430 - val_loss: 0.3210 - val_accuracy: 0.7883
# Epoch 3/50
# 274/274 [==============================] - 9s 32ms/step - loss: 0.1586 - accuracy: 0.8965 - val_loss: 0.3440 - val_accuracy: 0.7938
# Epoch 3: early stopping
# 69/69 [==============================] - 1s 8ms/step
# Training - 3
#               precision    recall  f1-score   support
#
#            0       0.68      0.77      0.72       681
#            1       0.43      0.09      0.15       235
#            2       0.87      0.94      0.90      1271
#
#     accuracy                           0.79      2187
#    macro avg       0.66      0.60      0.59      2187
# weighted avg       0.76      0.79      0.77      2187
#
# ======================================================
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 90, 200)           1000000
#
#  conv1d_4 (Conv1D)           (None, 86, 128)           128128
#
#  global_max_pooling1d_4 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_8 (Dense)             (None, 10)                1290
#
#  dense_9 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 1129451 (4.31 MB)
# Trainable params: 1129451 (4.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 274/274 [==============================] - 10s 33ms/step - loss: 0.3770 - accuracy: 0.7379 - val_loss: 0.3081 - val_accuracy: 0.7979
# Epoch 2/50
# 274/274 [==============================] - 9s 32ms/step - loss: 0.2501 - accuracy: 0.8339 - val_loss: 0.3027 - val_accuracy: 0.8052
# Epoch 3/50
# 274/274 [==============================] - 9s 32ms/step - loss: 0.1722 - accuracy: 0.8883 - val_loss: 0.3263 - val_accuracy: 0.7997
# Epoch 4/50
# 274/274 [==============================] - 9s 32ms/step - loss: 0.0929 - accuracy: 0.9530 - val_loss: 0.4060 - val_accuracy: 0.7810
# Epoch 4: early stopping
# 69/69 [==============================] - 1s 8ms/step
# Training - 4
#               precision    recall  f1-score   support
#
#            0       0.69      0.69      0.69       681
#            1       0.35      0.27      0.31       235
#            2       0.89      0.92      0.91      1271
#
#     accuracy                           0.78      2187
#    macro avg       0.64      0.63      0.63      2187
# weighted avg       0.77      0.78      0.77      2187
#
# ======================================================
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 90, 200)           1000000
#
#  conv1d_5 (Conv1D)           (None, 86, 128)           128128
#
#  global_max_pooling1d_5 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_10 (Dense)            (None, 10)                1290
#
#  dense_11 (Dense)            (None, 3)                 33
#
# =================================================================
# Total params: 1129451 (4.31 MB)
# Trainable params: 1129451 (4.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 274/274 [==============================] - 11s 34ms/step - loss: 0.3683 - accuracy: 0.7538 - val_loss: 0.3067 - val_accuracy: 0.7984
# Epoch 2/50
# 274/274 [==============================] - 9s 32ms/step - loss: 0.2469 - accuracy: 0.8431 - val_loss: 0.2989 - val_accuracy: 0.8057
# Epoch 3/50
# 274/274 [==============================] - 9s 33ms/step - loss: 0.1808 - accuracy: 0.8795 - val_loss: 0.3123 - val_accuracy: 0.8034
# Epoch 4/50
# 274/274 [==============================] - 9s 32ms/step - loss: 0.1210 - accuracy: 0.9259 - val_loss: 0.3828 - val_accuracy: 0.8038
# Epoch 4: early stopping
# 69/69 [==============================] - 1s 8ms/step
# Training - 5
#               precision    recall  f1-score   support
#
#            0       0.69      0.79      0.73       681
#            1       0.47      0.10      0.17       235
#            2       0.88      0.94      0.91      1271
#
#     accuracy                           0.80      2187
#    macro avg       0.68      0.61      0.60      2187
# weighted avg       0.78      0.80      0.78      2187
#
# ======================================================
#
#
#
# Rata-rata Accuracy:  0.7857

# %%
plt.style.use('ggplot')

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12,5))
    
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

# %matplotlib inline
plot_history(history)

# %%
# menyimpan model

model.save('model.h5')
print("Model has created!")
# Out:
# C:\Users\Reza Fakhrurrozi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model has created!

# %%
input_text = """Rasa syukur, cukup"""

def cleansing(sent):
    string = sent.lower()
    string = re.sub(r'[^a-zA-Z0-9]', ' ', string)
    return string

sentiment = ['positive', 'neutral', 'negative']

text = [cleansing(input_text)]
predicted = tokenizer.texts_to_sequences(text)
guess = pad_sequences(predicted, maxlen=X.shape[1])

model = load_model('model.h5')
prediction = model.predict(guess)
polarity = np.argmax(prediction[0])
hasil = sentiment[polarity]

print("Text: ", text[0])
print("Sentiment: ", hasil)
# Out:
# 1/1 [==============================] - 0s 173ms/step
# Text:  rasa syukur  cukup
# Sentiment:  negative
